# %%
from image_caption_keras import *
from data_helper import *

# %%
train = pd.read_csv('../data/train.csv')
cap_vector, tokenizer, index_word, max_len= get_word_index(train['captions'])
vocab_size = len(index_word) + 1

# %%
model = tf.keras.models.load_model('models_checkpoints/model_sample_20000.h5')

# %%
path = '../train2014/COCO_train2014_000000190271.jpg'
img_feature = get_InceptionV3_image_feature(path)
beam_search_3 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=3)
beam_search_5 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=5)
beam_search_7 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=7)
print('Beam Search, k=3:', beam_search_3)
print('Beam Search, k=5:', beam_search_5)
print('Beam Search, k=7:', beam_search_7)
img = Image.open(path)
plt.imshow(img)
# Out:
# Beam Search, k=3: a small bird sitting on top of a body of water
# Beam Search, k=5: a couple of birds standing on top of a body of water
# Beam Search, k=7: a couple of birds standing on top of a body of water

# %%
path = '../train2014/COCO_train2014_000000241408.jpg'
img_feature = get_InceptionV3_image_feature(path)
beam_search_3 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=3)
beam_search_5 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=5)
beam_search_7 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=7)
print('Beam Search, k=3:', beam_search_3)
print('Beam Search, k=5:', beam_search_5)
print('Beam Search, k=7:', beam_search_7)
img = Image.open(path)
plt.imshow(img)
# Out:
# Beam Search, k=3: a bowl of food on a wooden table
# Beam Search, k=5: a table topped with a piece of cake on top
# Beam Search, k=7: a piece of cake sitting on top of a cutting board

# %%
path = '../train2014/COCO_train2014_000000031729.jpg'
img_feature = get_InceptionV3_image_feature(path)
beam_search_3 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=3)
beam_search_5 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=5)
beam_search_7 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=7)
print('Beam Search, k=3:', beam_search_3)
print('Beam Search, k=5:', beam_search_5)
print('Beam Search, k=7:', beam_search_7)
img = Image.open(path)
plt.imshow(img)
# Out:
# Beam Search, k=3: a group of people are sitting at a table
# Beam Search, k=5: a group of people sitting at a table
# Beam Search, k=7: a group of people sitting at a table together

# %%
path = '../train2014/COCO_train2014_000000500987.jpg'
img_feature = get_InceptionV3_image_feature(path)
beam_search_3 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=3)
beam_search_5 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=5)
beam_search_7 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=7)
print('Beam Search, k=3:', beam_search_3)
print('Beam Search, k=5:', beam_search_5)
print('Beam Search, k=7:', beam_search_7)
img = Image.open(path)
plt.imshow(img)
# Out:
# Beam Search, k=3: a train is pulling into a train station
# Beam Search, k=5: a train is pulling into a train station
# Beam Search, k=7: there is a train coming down the tracks

# %%
path = '../train2014/COCO_train2014_000000130271.jpg'
img_feature = get_InceptionV3_image_feature(path)
beam_search_3 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=3)
beam_search_5 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=5)
beam_search_7 = beam_search(model, max_len, tokenizer.word_index, index_word, img_feature, beam_index=7)
print('Beam Search, k=3:', beam_search_3)
print('Beam Search, k=5:', beam_search_5)
print('Beam Search, k=7:', beam_search_7)
img = Image.open(path)
plt.imshow(img)
# Out:
# Beam Search, k=3: a man holding a cell phone in his mouth
# Beam Search, k=5: a man holding a cell phone in his mouth
# Beam Search, k=7: there is a picture of a little girl holding a hot dog
